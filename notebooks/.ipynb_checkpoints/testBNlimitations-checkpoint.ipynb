# %%
from pylab import *
import matplotlib.pyplot as plt
import os
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.lib.image as gim

# %%
bn=gum.loadBN("/Users/ludivanleeuwen/simulationTest/experiments/VlekNetwork/BNs/KB1_arbit_0.05.net")
ie=gum.LazyPropagation(bn)
ie.addAllTargets()
targets = ie.targets()
ie.addJointTarget(targets)
ie.jointPosterior(targets)
# Out:
# (pyAgrum.Potential<double>@0x7fb4f050a4e0)
#                     ||  jane_stabs_mark_w|
# mark_d|jane_a|jane_h||0        |1        |
# ------|------|------||---------|---------|
# 0     |0     |0     || 0.2400  | 0.0000  |
# 1     |0     |0     || 0.0000  | 0.0000  |
# 0     |1     |0     || 0.0600  | 0.0000  |
# 1     |1     |0     || 0.0000  | 0.0000  |
# 0     |0     |1     || 0.5600  | 0.0000  |
# 1     |0     |1     || 0.0000  | 0.0000  |
# 0     |1     |1     || 0.1400  | 0.0000  |
# 1     |1     |1     || 0.0000  | 0.0000  |

# %%
bn=gum.loadBN("/Users/ludivanleeuwen/simulationTest/experiments/VlekNetwork/BNs/KB1_arbit_0.05.net")
ie=gum.LazyPropagation(bn)

ie.addAllTargets()
targets = ie.targets()
ie.addJointTarget(targets)
ie.jointPosterior(targets)

ie.addEvidence('jane_and_mark_fight', 1)
#print(ie.posterior('mark_dies'))
print(ie.jointPosterior(targets))

ie.addEvidence('jane_has_knife', 1)
print(ie.posterior('mark_dies'))
print(ie.jointPosterior(targets))




ie.addEvidence('jane_stabs_mark_with_knife', 1)
print(ie.jointPosterior(targets))


print(ie.posterior('mark_dies'))
print(ie.posterior('jane_has_knife'))





#gnb.showInference(bn,evs={})
#gnb.showInference(bn,evs={'jane_has_knife':1, 'jane_stabs_mark_with_knife':1})
# Out:
#                     ||  jane_has_knife   |
# jane_s|mark_d|jane_a||0        |1        |
# ------|------|------||---------|---------|
# 0     |0     |0     || 0.0000  | 0.0000  |
# 1     |0     |0     || 0.0000  | 0.0000  |
# 0     |1     |0     || 0.0000  | 0.0000  |
# 1     |1     |0     || 0.0000  | 0.0000  |
# 0     |0     |1     || 0.3000  | 0.7000  |
# 1     |0     |1     || 0.0000  | 0.0000  |
# 0     |1     |1     || 0.0000  | 0.0000  |
# 1     |1     |1     || 0.0000  | 0.0000  |
#
#
#   mark_dies        |
# 0        |1        |
# ---------|---------|
#  1.0000  | 0.0000  |
#
#
#                     ||  jane_stabs_mark_w|
# mark_d|jane_h|jane_a||0        |1        |
# ------|------|------||---------|---------|
# 0     |0     |0     || 0.0000  | 0.0000  |
# 1     |0     |0     || 0.0000  | 0.0000  |
# 0     |1     |0     || 0.0000  | 0.0000  |
# 1     |1     |0     || 0.0000  | 0.0000  |
# 0     |0     |1     || 0.0000  | 0.0000  |
# 1     |0     |1     || 0.0000  | 0.0000  |
# 0     |1     |1     || 1.0000  | 0.0000  |
# 1     |1     |1     || 0.0000  | 0.0000  |
#
#
#                     ||  jane_stabs_mark_w|
# mark_d|jane_h|jane_a||0        |1        |
# ------|------|------||---------|---------|
# 0     |0     |0     || 0.0000  | 0.0000  |
# 1     |0     |0     || 0.0000  | 0.0000  |
# 0     |1     |0     || 0.0000  | 0.0000  |
# 1     |1     |0     || 0.0000  | 0.0000  |
# 0     |0     |1     || 0.0000  | 0.0000  |
# 1     |0     |1     || 0.0000  | 0.0000  |
# 0     |1     |1     || 0.0000  | 0.3000  |
# 1     |1     |1     || 0.0000  | 0.7000  |
#
#
#   mark_dies        |
# 0        |1        |
# ---------|---------|
#  0.3000  | 0.7000  |
#
#
#   jane_has_knife   |
# 0        |1        |
# ---------|---------|
#  0.0000  | 1.0000  |
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-72-8392c9c64b0f> in <module>
#      30
#      31 #gnb.showInference(bn,evs={})
# ---> 32 gnb.showInference(bn,evs={'jane_has_knife':1, 'jane_stabs_mark_with_knife':1})
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/lib/notebook.py in showInference(model, **kwargs)
#     730     size = gum.config["notebook", "default_graph_inference_size"]
#     731
# --> 732   showGraph(prepareShowInference(model, **kwargs), size)
#     733
#     734
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/lib/image.py in prepareShowInference(model, engine, evs, targets, size, nodeColor, factorColor, arcWidth, arcColor, cmap, cmapArc, graph, view)
#     104     if engine is None:
#     105       engine = gum.LazyPropagation(model)
# --> 106     return BNinference2dot(model, size=size, engine=engine, evs=evs, targets=targets, nodeColor=nodeColor,
#     107                            arcWidth=arcWidth,
#     108                            arcColor=arcColor,
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/lib/bn2graph.py in BNinference2dot(bn, size, engine, evs, targets, nodeColor, arcWidth, arcColor, cmapNode, cmapArc, dag)
#     236                  hashlib.md5(name.encode()).hexdigest() + "." + \
#     237                  gum.config["notebook", "graph_format"]
# --> 238       proba_histogram.saveFigProba(ie.posterior(name), filename, bgcol=bgcol)
#     239       dotstr += f' "{name}" [shape=rectangle,image="{filename}",label="", {colorattribute}];\n'
#     240     else:
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/pyAgrum.py in posterior(self, *args)
#   12300
#   12301         """
# > 12302         return _pyAgrum.LazyPropagation_posterior(self, *args)
#   12303
#   12304     def eraseAllJointTargets(self) -> None:
#
# Exception: [pyAgrum] Several evidence/CPT are incompatible together (proba=0): some evidence entered into the Bayes net are incompatible (their joint proba = 0)

# %%
ie.addEvidence('jane_stabs_mark_with_knife', 1)
ie.makeInference()
ie.posterior('mark_dies')
#gnb.showPosterior(bn, evs={'jane_stabs_mark_with_knife':1}, target='jane_has_knife')
# Out:
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# <ipython-input-59-41edfb7d4661> in <module>
# ----> 1 ie.addEvidence('jane_stabs_mark_with_knife', 1)
#       2 ie.makeInference()
#       3 ie.posterior('mark_dies')
#       4 #gnb.showPosterior(bn, evs={'jane_stabs_mark_with_knife':1}, target='jane_has_knife')
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/pyAgrum.py in addEvidence(self, *args)
#   11981
#   11982         """
# > 11983         return _pyAgrum.LazyPropagation_addEvidence(self, *args)
#   11984
#   11985     def chgEvidence(self, *args) -> None:
#
# InvalidArgument: [pyAgrum] Invalid argument:  node 2 already has an evidence. Please use chgEvidence().

# %%
gnb.showInference(bn, evs={'jane_stabs_mark_with_knife':1})
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-35-367982ee8e38> in <module>
# ----> 1 gnb.showInference(bn, evs={'jane_stabs_mark_with_knife':1})
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/lib/notebook.py in showInference(model, **kwargs)
#     730     size = gum.config["notebook", "default_graph_inference_size"]
#     731
# --> 732   showGraph(prepareShowInference(model, **kwargs), size)
#     733
#     734
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/lib/image.py in prepareShowInference(model, engine, evs, targets, size, nodeColor, factorColor, arcWidth, arcColor, cmap, cmapArc, graph, view)
#     104     if engine is None:
#     105       engine = gum.LazyPropagation(model)
# --> 106     return BNinference2dot(model, size=size, engine=engine, evs=evs, targets=targets, nodeColor=nodeColor,
#     107                            arcWidth=arcWidth,
#     108                            arcColor=arcColor,
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/lib/bn2graph.py in BNinference2dot(bn, size, engine, evs, targets, nodeColor, arcWidth, arcColor, cmapNode, cmapArc, dag)
#     236                  hashlib.md5(name.encode()).hexdigest() + "." + \
#     237                  gum.config["notebook", "graph_format"]
# --> 238       proba_histogram.saveFigProba(ie.posterior(name), filename, bgcol=bgcol)
#     239       dotstr += f' "{name}" [shape=rectangle,image="{filename}",label="", {colorattribute}];\n'
#     240     else:
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/pyAgrum.py in posterior(self, *args)
#   12300
#   12301         """
# > 12302         return _pyAgrum.LazyPropagation_posterior(self, *args)
#   12303
#   12304     def eraseAllJointTargets(self) -> None:
#
# Exception: [pyAgrum] Several evidence/CPT are incompatible together (proba=0): some evidence entered into the Bayes net are incompatible (their joint proba = 0)

# %%
ie=gum.LazyPropagation(bn)
print(bn.cpt('jane_stabs_mark_with_knife'))
gnb.showInference(bn,evs={'jane_has_knife': 0})
print(ie.posterior('jane_stabs_mark_with_knife'))
ie.addEvidence('jane_stabs_mark_with_knife', 1)
print(ie.posterior('jane_stabs_mark_with_knife'))
# Out:
# ---------------------------------------------------------------------------
# NotFound                                  Traceback (most recent call last)
# <ipython-input-22-846c367048a1> in <module>
#       1 bn=gum.loadBN("/Users/ludivanleeuwen/simulationTest/experiments/VlekNetwork/BNs/KB2_arbit_0.33.net")
#       2 ie=gum.LazyPropagation(bn)
# ----> 3 print(bn.cpt('jane_stabs_mark_with_knife'))
#       4 gnb.showInference(bn,evs={'jane_has_knife': 0})
#       5 print(ie.posterior('jane_stabs_mark_with_knife'))
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/pyAgrum.py in cpt(self, *args)
#    8519
#    8520         """
# -> 8521         return _pyAgrum.BayesNet_cpt(self, *args)
#    8522
#    8523     def variableNodeMap(self) -> "pyAgrum.VariableNodeMap":
#
# NotFound: [pyAgrum] Object not found: No element with the key <jane_stabs_mark_with_knife>

# %%
bn=gum.loadBN("/Users/ludivanleeuwen/simulationTest/experiments/VlekNetwork/BNs/KBfull.net")
ie=gum.LazyPropagation(bn)
gnb.showInference(bn,evs={'jane_has_knife': 0, 'jane_threatens_mark_with_knife':1})

# %%
ie.evidenceImpact("mark_dies",["jane_and_mark_fight","jane_has_knife","jane_stabs_mark_with_knife"])
# Out:
# (pyAgrum.Potential<double>@0x7fdaa00c6050)
#       ||  mark_dies        |
# jane_s||0        |1        |
# ------||---------|---------|
# 0     || 1.0000  | 0.0000  |
# 1     || 0.2723  | 0.7277  |

# %%
print(gum.getPosterior(bn,{'jane_stabs_mark_with_knife':1}, 
                      'mark_dies').tolist())

ie.chgEvidence('jane_stabs_mark_with_knife', [0.1, 0.1])
print(ie.posterior('mark_dies'))

ie.chgEvidence('jane_stabs_mark_with_knife', 1)
print(ie.posterior('mark_dies'))

#gnb.showInference(bn)
#ie.addEvidence('jane_stabs_mark_with_knife', 1)
#ie.evidenceImpact('mark_dies', evs={ 'jane_has_knife','jane_and_mark_fight'})
# Out:
# [0.27227699756622314, 0.7277230024337769]
# ---------------------------------------------------------------------------
# InvalidArgument                           Traceback (most recent call last)
# <ipython-input-63-4ec1c6fe61cd> in <module>
#       2                       'mark_dies').tolist())
#       3
# ----> 4 ie.chgEvidence('jane_stabs_mark_with_knife', [0.1, 0.1])
#       5 print(ie.posterior('mark_dies'))
#       6
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/pyAgrum.py in chgEvidence(self, *args)
#   12015
#   12016         """
# > 12017         return _pyAgrum.LazyPropagation_chgEvidence(self, *args)
#   12018
#   12019     def hasEvidence(self, *args) -> bool:
#
# InvalidArgument: [pyAgrum] Invalid argument: 2 has no evidence. Please use addEvidence().

# %%
import time

r = range(0, 100, 2)
xs = [x/100.0 for x in r]
tf = time.time()

ys = []
val = 0
for x in r:
    print(x/100.0)
    
    val = gum.getPosterior(bn, {'jane_stabs_mark_with_knife':0.5},'mark_dies').tolist()
    print(val)
    ys.append(val)
    
delta=time.time()-tf
p=plot(xs,ys)
legend(p, [bn.variableFromName('mark_dies').label(i)
          for i in range(bn,variableFromName('mark_dies').domainSize())],loc=7);
title('mark dies (100 inferences in %d ms)'%delta);
ylabel('posterior probability');
xlabel('evidence on jane stabs mark with knife');
# Out:
# 0.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-32a824ab3868> in <module>
#       9 for x in r:
#      10     print(x/100.0)
# ---> 11     val = gum.getPosterior(bn, {'jane_stabs_mark_with_knife':0.5},'mark_dies').tolist()
#      12     print(val)
#      13     ys.append(val)
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/__init__.py in getPosterior(model, evs, target)
#     466     raise InvalidArgument("Argument model should be a PGM (BayesNet or MarkovNet")
#     467
# --> 468   inf.setEvidence(evs)
#     469   inf.addTarget(target)
#     470   inf.makeInference()
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/pyAgrum.py in setEvidence(self, evidces)
#   13297         self.eraseAllEvidence()
#   13298         for k,v in evidces.items():
# > 13299             self.addEvidence(k,v)
#   13300
#   13301
#
# /usr/local/lib/python3.8/site-packages/pyAgrum/pyAgrum.py in addEvidence(self, *args)
#   13610
#   13611         """
# > 13612         return _pyAgrum.VariableElimination_addEvidence(self, *args)
#   13613
#   13614     def chgEvidence(self, *args) -> None:
#
# TypeError: Wrong number or type of arguments for overloaded function 'VariableElimination_addEvidence'.
#   Possible C/C++ prototypes are:
#     gum::VariableElimination< double >::addEvidence(gum::NodeId const,gum::Idx const)
#     gum::VariableElimination< double >::addEvidence(std::string const &,gum::Idx const)
#     gum::VariableElimination< double >::addEvidence(gum::NodeId const,std::string const &)
#     gum::VariableElimination< double >::addEvidence(std::string const &,std::string const &)
#     gum::VariableElimination< double >::addEvidence(gum::NodeId const,std::vector< double,std::allocator< double > > const &)
#     gum::VariableElimination< double >::addEvidence(std::string const &,std::vector< double,std::allocator< double > > const &)

# %%
#bn=gum.loadBN("/Users/ludivanleeuwen/simulationTest/experiments/GroteMarkt/BNs/GroteMarkt.net")
bn=gum.loadBN("/Users/ludivanleeuwen/simulationTest/experiments/VlekNetwork/BNs/KB1.net")
ie=gum.LazyPropagation(bn)
gnb.showInference(bn,evs={})
#gim.exportInference(model=bnK2, filename="Report/images/Kb.pdf", engine=ie, evs={})

# %%
cr = gum.CredalNet(bn, bn)
gnb.show(cr)
#gnb.flow.row(bn,gnb.getInference(bn))


cr.bnToCredal(beta=1e-10,oneNet=False)
cr.computeBinaryCPTMinMax()
#print(cr)

# %%
from pylab import *
import matplotlib.pyplot as plt
import os
import pyAgrum as gum
import pyAgrum.lib.notebook as gnb
import pyAgrum.lib.image as gim


#bn=gum.loadBN("/Users/ludivanleeuwen/simulationTest/experiments/GroteMarkt/BNs/GroteMarkt.net")

bn=gum.loadBN("/Users/ludivanleeuwen/simulationTest/experiments/VlekNetwork/BNs/KB1.net")



cr=gum.CredalNet(bn,bn)
cr.bnToCredal(beta=0.0001,oneNet=False)
print(cr)
cr.computeBinaryCPTMinMax()
ielbp=gum.CNLoopyPropagation(cr)  
gnb.showInference(cr,targets={"mark_dies"},engine=ielbp)
# Out:
# ** pyAgrum** For better visualizations, please install matplotlib-inline.
#
# jane_and_mark_fight:Labelized(<0,1>)
# <> : [[0.791098 , 0.208902] , [0.786411 , 0.213589]]
#
# jane_has_knife:Labelized(<0,1>)
# <> : [[0.361184 , 0.638816] , [0.270173 , 0.729827]]
#
# jane_stabs_mark_with_knife:Labelized(<0,1>)
# <jane_has_knife:0|jane_and_mark_fight:0> : [[0.999989 , 1.06282e-05] , [0.998301 , 0.00169886]]
# <jane_has_knife:1|jane_and_mark_fight:0> : [[0.999995 , 4.49443e-06] , [0.998307 , 0.00169268]]
# <jane_has_knife:0|jane_and_mark_fight:1> : [[0.99996 , 3.99933e-05] , [0.998272 , 0.00172846]]
# <jane_has_knife:1|jane_and_mark_fight:1> : [[0.979544 , 0.0204556] , [0.977688 , 0.0223117]]
#
# mark_dies:Labelized(<0,1>)
# <jane_stabs_mark_with_knife:0> : [[0.999995 , 5.00663e-06] , [0.998307 , 0.0016932]]
# <jane_stabs_mark_with_knife:1> : [[0.351478 , 0.648522] , [0.242644 , 0.757356]]

# %%
#gnb.showInference(bn,evs={"jane_and_mark_fight":1, "jane_has_knife":1, "jane_stabs_mark_with_knife":1, "mark_dies":1})
ie=gum.LazyPropagation(bn)
ie.posterior("jane_has_knife")
gnb.showInference(bn,evs={"mark_dies":0, 
                          #"jane_stabs_mark_with_knife":0, 
                          "jane_and_mark_fight":0,
                          "jane_has_knife":1})
#gnb.showInference(bn,evs={"jane_has_knife":1})

# %%
bn.cpt("jane_and_mark_fight")
# Out:
# (pyAgrum.Potential<double>@0x7f8fa9cc4c50)
#   jane_and_mark_fig|
# 0        |1        |
# ---------|---------|
#  1.0000  | 0.0000  |

# %%
bn.cpt("jane_has_knife")
# Out:
# (pyAgrum.Potential<double>@0x7f8fa9cc23d0)
#   jane_has_knife   |
# 0        |1        |
# ---------|---------|
#  0.5000  | 0.5000  |

# %%
bn.cpt("mark_dies")
# Out:
# (pyAgrum.Potential<double>@0x7f8fa9cef780)
#       ||  mark_dies        |
# jane_s||0        |1        |
# ------||---------|---------|
# 0     || 1.0000  | 0.0000  |
# 1     || 0.5000  | 0.5000  |

# %%
bn.cpt("jane_stabs_mark_with_knife")
# Out:
# (pyAgrum.Potential<double>@0x7f8fa9cd2d60)
#              ||  jane_stabs_mark_w|
# jane_a|jane_h||0        |1        |
# ------|------||---------|---------|
# 0     |0     || 1.0000  | 0.0000  |
# 1     |0     || 1.0000  | 0.0000  |
# 0     |1     || 1.0000  | 0.0000  |
# 1     |1     || 1.0000  | 0.0000  |
